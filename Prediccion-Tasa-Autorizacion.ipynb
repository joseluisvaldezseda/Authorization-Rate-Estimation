# %% [markdown]
# # Analizamos el desbalance existente en las clases

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer el archivo CSV
file_name = "Prueba final PoC Gain Dynamics.csv"
df = pd.read_csv(file_name)

# Contar la frecuencia de cada categoría en 'CLASIFICACION'
distribucion = df['CLASIFICACION'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']

# Definir el orden específico de las categorías
orden_clases = ['ALTA', 'MEDIA', 'BAJA']

# Definir colores específicos (mismos que en la imagen anterior)
colores = ['#3E4A72', '#2A7F77', '#74B76F']

plt.figure(figsize=(8, 6))
sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_42240\124541118.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

# %%
import pandas as pd

# Leer el archivo
# Nombre del archivo
file_name = "Prueba final PoC Gain Dynamics.csv"

# Leer el archivo Excel

df = pd.read_csv(file_name)

# Asegurarnos de que la columna 'COLONIA' exista (en tu dataset puede llamarse diferente, ajusta si es necesario)
# Si la columna tiene otro nombre, cámbialo por el correcto.
if 'COLONIA' not in df.columns:
    print("La columna 'COLONIA' no existe. Por favor verifica el nombre.")
else:
    # Agrupar por 'nom_ent' y contar las colonias
    tabla_colonias = df.groupby('ESTADO')['COLONIA'].nunique().reset_index()

    # Renombrar columnas para mayor claridad
    tabla_colonias.columns = ['ESTADO', 'Numero_Colonias']

    # Ordenar de mayor a menor
    tabla_colonias = tabla_colonias.sort_values(by='Numero_Colonias', ascending=False)

    # Mostrar tabla
    print(tabla_colonias)

distribucion = df['CLASIFICACION'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']
distribucion['PORCENTAJE'] = (distribucion['FRECUENCIA'] / distribucion['FRECUENCIA'].sum()) * 100
print(distribucion)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.countplot(x='CLASIFICACION', data=df, palette='viridis')
plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
#                   ESTADO  Numero_Colonias
# 4                JALISCO              839
# 2             GUANAJUATO              835
# 6    MICHOACAN DE OCAMPO              585
# 1                 COLIMA              475
# 7                NAYARIT              410
# 9        SAN LUIS POTOSI              270
# 0         AGUASCALIENTES              215
# 10             ZACATECAS              215
# 5                 MEXICO              133
# 3                HIDALGO              126
# 8   QUERETARO DE ARTEAGA              116
#   CLASIFICACION  FRECUENCIA  PORCENTAJE
# 0         MEDIA        3875   69.147038
# 1          ALTA         869   15.506781
# 2          BAJA         860   15.346181
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_42240\4272821496.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer el archivo
file_name = "NSE de Colima con Aceptacion.xlsx"
df = pd.read_excel(file_name)

# Contar la frecuencia de cada categoría en 'Aceptacion2'
distribucion = df['Aceptacion2'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']

# Definir el orden específico de las categorías
orden_clases = ['ALTA', 'MEDIA', 'BAJA']

# Definir colores específicos
colores = ['#3E4A72', '#2A7F77', '#74B76F']

plt.figure(figsize=(8, 6))
sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_42240\3561314356.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

# %%
import pandas as pd

# Leer el archivo
# Nombre del archivo
file_name = "NSE de Colima con Aceptacion.xlsx"

# Leer el archivo Excel

df = pd.read_excel(file_name)

# Asegurarnos de que la columna 'COLONIA' exista (en tu dataset puede llamarse diferente, ajusta si es necesario)
# Si la columna tiene otro nombre, cámbialo por el correcto.
if 'NOMBRE' not in df.columns:
    print("La columna 'COLONIA' no existe. Por favor verifica el nombre.")
else:
    # Agrupar por 'nom_ent' y contar las colonias
    tabla_colonias = df.groupby('nom_ent')['NOMBRE'].nunique().reset_index()

    # Renombrar columnas para mayor claridad
    tabla_colonias.columns = ['Entidad', 'Numero_Colonias']

    # Ordenar de mayor a menor
    tabla_colonias = tabla_colonias.sort_values(by='Numero_Colonias', ascending=False)

    # Mostrar tabla
    print(tabla_colonias)

distribucion = df['Aceptacion2'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']
distribucion['PORCENTAJE'] = (distribucion['FRECUENCIA'] / distribucion['FRECUENCIA'].sum()) * 100
print(distribucion)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.countplot(x='Aceptacion2', data=df, palette='viridis')
plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
#   Entidad  Numero_Colonias
# 0  Colima               12
#   CLASIFICACION  FRECUENCIA  PORCENTAJE
# 0          BAJA         234   45.086705
# 1         MEDIA         179   34.489403
# 2          ALTA         106   20.423892
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_16400\251128071.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Aceptacion2', data=df, palette='viridis')

# %%
import pandas as pd

# Leer el archivo
file_name = "Dataset-Prediccion.csv"
df = pd.read_csv(file_name, encoding='latin-1')

# Asegurarnos de que la columna 'COLONIA' exista (en tu dataset puede llamarse diferente, ajusta si es necesario)
# Si la columna tiene otro nombre, cámbialo por el correcto.
if 'COLONIA' not in df.columns:
    print("La columna 'COLONIA' no existe. Por favor verifica el nombre.")
else:
    # Agrupar por 'nom_ent' y contar las colonias
    tabla_colonias = df.groupby('nom_ent')['COLONIA'].nunique().reset_index()

    # Renombrar columnas para mayor claridad
    tabla_colonias.columns = ['Entidad', 'Numero_Colonias']

    # Ordenar de mayor a menor
    tabla_colonias = tabla_colonias.sort_values(by='Numero_Colonias', ascending=False)

    # Mostrar tabla
    print(tabla_colonias)

distribucion = df['CLASIFICACION'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']
distribucion['PORCENTAJE'] = (distribucion['FRECUENCIA'] / distribucion['FRECUENCIA'].sum()) * 100
print(distribucion)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.countplot(x='CLASIFICACION', data=df, palette='viridis')
plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_16400\3405942491.py:5: DtypeWarning: Columns (247) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, encoding='latin-1')
#             Entidad  Numero_Colonias
# 2        GUANAJUATO              420
# 4           JALISCO              393
# 6         MICHOACAN              333
# 1            COLIMA              304
# 7           NAYARIT              207
# 9   SAN LUIS POTOSI              159
# 0    AGUASCALIENTES              136
# 10        ZACATECAS              124
# 8         QUERETARO               78
# 3           HIDALGO               46
# 5            MEXICO               34
#   CLASIFICACION  FRECUENCIA  PORCENTAJE
# 0         MEDIA       74880   74.137146
# 1          BAJA       14499   14.355161
# 2          ALTA       11623   11.507693
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_16400\3405942491.py:33: FutureWarning:
#
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Leer el archivo CSV
file_name = "Dataset-Prediccion.csv"
df = pd.read_csv(file_name, encoding='latin-1')

# Contar la frecuencia de cada categoría en 'CLASIFICACION'
distribucion = df['CLASIFICACION'].value_counts().reset_index()
distribucion.columns = ['CLASIFICACION', 'FRECUENCIA']

# Definir el orden específico de las categorías
orden_clases = ['ALTA', 'MEDIA', 'BAJA']

# Definir colores específicos (mismos que en la imagen anterior)
colores = ['#3E4A72', '#2A7F77', '#74B76F']

plt.figure(figsize=(8, 6))
sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

plt.title('Distribución de Clases en CLASIFICACION')
plt.xlabel('Clase')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_42240\831064694.py:7: DtypeWarning: Columns (247) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, encoding='latin-1')
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_42240\831064694.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='CLASIFICACION', y='FRECUENCIA', data=distribucion, order=orden_clases, palette=colores)

# %% [markdown]
# # Modelo de Random Forest para Tasa de Autorización (Sin Agrupar)

# %%
import pandas as pd
from imblearn.over_sampling import BorderlineSMOTE
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold, cross_val_score
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns


# Nombre del archivo
file_name = "Dataset-Prediccion.csv"

# Leer el archivo csv

df = pd.read_csv(file_name, encoding='latin-1')

# Función para limpiar y convertir columnas a numérico, eliminando asteriscos
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')


# Limpiar nombres de columnas y ajustar
df.columns = df.columns.str.strip().str.lower().str.replace('\n', ' ')

# Universo:
total_viviendas = limpiar_y_convertir(df['tvivparhab'])  # Total de viviendas particulares habitadas
poblacion_activa = limpiar_y_convertir(df['pea'])
poblacion_total = limpiar_y_convertir(df['pobtot'])

# Establecer orden y codificar `nse`
orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
df['nse'] = pd.Categorical(df['nse'], categories=orden_clases, ordered=True)
df['nse'] = df['nse'].cat.codes  # Convertir categorías a números (0 para 'E', 1 para 'D', etc.)


df['vph_excsa'] = limpiar_y_convertir(df['vph_excsa']) * 100 / total_viviendas
df['vph_autom'] = limpiar_y_convertir(df['vph_autom']) * 100 / total_viviendas
df['vph_inter'] = limpiar_y_convertir(df['vph_inter']) * 100 / total_viviendas
df['pocupada'] = limpiar_y_convertir(df['pocupada']) * 100 / poblacion_activa  # Población Económicamente Activa
df['pder_ss'] = limpiar_y_convertir(df['pder_ss']) * 100 / poblacion_total 
df['p18ym_pb'] = limpiar_y_convertir(df['p18ym_pb']) * 100 / poblacion_activa
df['vph_3ymasc'] = limpiar_y_convertir(df['vph_3ymasc']) * 100 / total_viviendas
df['vph_stvp'] = limpiar_y_convertir(df['vph_stvp']) * 100 / total_viviendas
df['vph_pc'] = limpiar_y_convertir(df['vph_pc']) * 100 / total_viviendas
df['vph_cvj'] = limpiar_y_convertir(df['vph_cvj']) * 100 / total_viviendas
df['vph_2ymasd'] = limpiar_y_convertir(df['vph_2ymasd']) * 100 / total_viviendas
df['vph_moto'] = limpiar_y_convertir(df['vph_moto']) * 100 / total_viviendas
df['vph_bici'] = limpiar_y_convertir(df['vph_bici']) * 100 / total_viviendas
df['vph_lavad'] = limpiar_y_convertir(df['vph_lavad']) * 100 / total_viviendas
df['vph_hmicro'] = limpiar_y_convertir(df['vph_hmicro']) * 100 / total_viviendas
df['vph_refri'] = limpiar_y_convertir(df['vph_refri']) * 100 / total_viviendas
df['vph_telef'] = limpiar_y_convertir(df['vph_telef']) * 100 / total_viviendas
df['vph_spmvpi'] = limpiar_y_convertir(df['vph_spmvpi']) * 100 / total_viviendas
df['vph_tv'] = limpiar_y_convertir(df['vph_tv']) * 100 / total_viviendas
df['vph_radio'] = limpiar_y_convertir(df['vph_radio']) * 100 / total_viviendas
df['pder_imss'] = limpiar_y_convertir(df['pder_imss']) * 100 / poblacion_activa 
df['vph_1cuart'] = limpiar_y_convertir(df['vph_1cuart']) * 100 / total_viviendas
df['p15sec_co'] = limpiar_y_convertir(df['p15sec_co']) * 100 / total_viviendas
df['p_0a2'] = limpiar_y_convertir(df['p_0a2']) * 100 / poblacion_total 
df['p_3a5'] = limpiar_y_convertir(df['p_3a5']) * 100 / poblacion_total 
df['p_6a11'] = limpiar_y_convertir(df['p_6a11']) * 100 / poblacion_total 
df['p_12a14'] = limpiar_y_convertir(df['p_12a14']) * 100 / poblacion_total 
df['p_15a17'] = limpiar_y_convertir(df['p_15a17']) * 100 / poblacion_total 
df['p_18a24'] = limpiar_y_convertir(df['p_18a24']) * 100 / poblacion_total 
df['pob15_64'] = limpiar_y_convertir(df['pob15_64']) * 100 / poblacion_total 
df['p_60ymas'] = limpiar_y_convertir(df['p_60ymas']) * 100 / poblacion_total 
df['p12ym_casa'] = limpiar_y_convertir(df['p12ym_casa']) * 100 / poblacion_total 
df['p12ym_solt'] = limpiar_y_convertir(df['p12ym_solt']) * 100 / poblacion_total 
#df['negocio'] = df['negocio'].map({'LA MARINA': 1, 'EL BODEGON': 5})

# Variables relevantes (selección de PCA o las usadas en tu dataset)
variables = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 
    'p18ym_pb', 'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 
    'vph_2ymasd', 'vph_moto', 'vph_bici', 'vph_lavad', 'vph_hmicro', 
    'vph_refri', 'vph_telef', 'vph_spmvpi', 'graproes' ,'nse','vph_tv',
    'vph_radio','pder_imss','vph_1cuart','p15sec_co','p15sec_co','p_0a2','p_3a5',
    'p_6a11','p_12a14','p_15a17','p_18a24','pob15_64','p_60ymas','p12ym_casa','p12ym_solt'
]

# Asegúrate de que 'Aceptacion' sea categórica

# Asegurarte de que 'aceptacion' sea categórica después del filtro
df['clasificacion'] = df['clasificacion'].astype('category')

# División de datos (X = variables predictoras, y = columna objetivo)
X = df[variables]
# Reemplazar valores infinitos por NaN
X.replace([np.inf, -np.inf], np.nan, inplace=True)

# Eliminar filas con NaN
X.dropna(inplace=True)

y = df['clasificacion']
y = y[X.index]

# Aplicar SMOTE para balancear las clases
smote = SMOTE(random_state=42, k_neighbors=6)
X_resampled, y_resampled = smote.fit_resample(X, y)
# Dividir datos balanceados en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.4, random_state=42, stratify=y_resampled)

# Crear y entrenar el modelo Random Forest
rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train, y_train)

# Predicciones
y_pred = rf_model.predict(X_test)

# Configurar validación cruzada estratificada
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Evaluar el modelo con validación cruzada
scores_accuracy = cross_val_score(rf_model, X_resampled, y_resampled, cv=skf, scoring='accuracy')
scores_f1_weighted = cross_val_score(rf_model, X_resampled, y_resampled, cv=skf, scoring='f1_weighted')

# Resultados
print("Resultados de Validación Cruzada:")
print(f"Precisión promedio: {scores_accuracy.mean():.2f} (+/- {scores_accuracy.std() * 2:.2f})")
print(f"F1-Score promedio (ponderado): {scores_f1_weighted.mean():.2f} (+/- {scores_f1_weighted.std() * 2:.2f})")

# Evaluación del modelo
print("Reporte de clasificación:")
print(classification_report(y_test, y_pred))

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d", xticklabels=y.cat.categories, yticklabels=y.cat.categories)
plt.title("Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()

# Importancia de las características
importancias = rf_model.feature_importances_
importancias_df = pd.DataFrame({'Variable': variables, 'Importancia': importancias}).sort_values(by='Importancia', ascending=False)

# Mostrar las importancias
plt.figure(figsize=(10, 6))
sns.barplot(x='Importancia', y='Variable', data=importancias_df, palette="viridis", ci=None)
plt.title("Importancia de las Características")
plt.xlabel("Importancia")
plt.ylabel("Variable")
plt.show()
import joblib

# Guardar el modelo entrenado
modelo_path = 'modelo_random_forest.pkl'
joblib.dump(rf_model, modelo_path)

print(f"Modelo guardado como: {modelo_path}")

# Mostrar tabla de importancias
print(importancias_df)
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_23588\2843563399.py:20: DtypeWarning: Columns (247) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, encoding='latin-1')
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_23588\2843563399.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_23588\2843563399.py:99: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.dropna(inplace=True)
# Resultados de Validación Cruzada:
# ...

# %% [markdown]
# # Modelo de Machine Learning para Tasa de Autorización (Agrupado)

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# Leer el archivo csv
file_name = "Dataset-Prediccion.csv"
df = pd.read_csv(file_name, encoding='latin-1')

# Función para limpiar y convertir columnas a numérico
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# Limpiar nombres de columnas
df.columns = df.columns.str.strip().str.lower().str.replace('\n', ' ')

# Columnas para agrupar (localidad / manzana)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df.columns]

# Variables que se deben sumar antes de calcular porcentaje
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar
for var in variables_a_sumar:
    if var in df.columns:
        df[var] = limpiar_y_convertir(df[var])

# Sumar variables por localidad
df_sums = df.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# Sumar variables totales para denominadores
df_totales = df.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# Unir sumas y totales
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# Calcular porcentajes con base en totales agrupados
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum']
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum']
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum']

# Agregar promedio numérico de NSE por localidad si existe la columna 'nse'
if 'nse' in df.columns:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df['nse'] = pd.Categorical(df['nse'], categories=orden_clases, ordered=True)
    df['nse_num'] = df['nse'].cat.codes
    df_nse_prom = df.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# Seleccionar variables para modelo: usar solo las variables porcentuales y 'nse_promedio' si existe
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns:
    variables_pct.append('nse_promedio')

# El target 'clasificacion' debe estar en df (agrupar si es necesario)
if 'clasificacion' not in df.columns:
    raise ValueError("La columna 'clasificacion' no está en el dataset original.")
# Agrupar clasificación por localidad (mayoría o modo)
df_clasificacion = df.groupby(columnas_grupo)['clasificacion'].agg(lambda x: x.mode()[0] if not x.mode().empty else np.nan).reset_index()

# Unir con df_totales
df_model = pd.merge(df_totales, df_clasificacion, on=columnas_grupo, how='left')

# Eliminar filas sin clasificación
df_model = df_model.dropna(subset=['clasificacion'])

# Preparar datos para modelo
X = df_model[variables_pct]
y = df_model['clasificacion'].astype('category')

# Reemplazar inf y NaN
X.replace([np.inf, -np.inf], np.nan, inplace=True)
X.fillna(X.median(), inplace=True)

# Balancear clases con SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Dividir en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.3, random_state=42, stratify=y_resampled
)

# Entrenar modelo Random Forest
rf_model = RandomForestClassifier(n_estimators=200, random_state=42)
rf_model.fit(X_train, y_train)

# Predecir y evaluar
y_pred = rf_model.predict(X_test)

print("Reporte de clasificación:")
print(classification_report(y_test, y_pred))

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_matrix, annot=True, cmap="Blues", fmt="d",
            xticklabels=y.cat.categories, yticklabels=y.cat.categories)
plt.title("Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Real")
plt.show()

# Validación cruzada
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores_accuracy = cross_val_score(rf_model, X_resampled, y_resampled, cv=skf, scoring='accuracy')
scores_f1 = cross_val_score(rf_model, X_resampled, y_resampled, cv=skf, scoring='f1_weighted')

print("Validación cruzada:")
print(f"Precisión promedio: {scores_accuracy.mean():.3f} (+/- {scores_accuracy.std() * 2:.3f})")
print(f"F1-score promedio: {scores_f1.mean():.3f} (+/- {scores_f1.std() * 2:.3f})")

# Importancia de variables
importancias = rf_model.feature_importances_
importancias_df = pd.DataFrame({'Variable': variables_pct, 'Importancia': importancias}).sort_values(by='Importancia', ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x='Importancia', y='Variable', data=importancias_df, palette="viridis")
plt.title("Importancia de las Características")
plt.tight_layout()
plt.show()

print("\nImportancia de variables:")
print(importancias_df)

# Guardar modelo
modelo_path = "modelo_random_forest_agrupado.pkl"
joblib.dump(rf_model, modelo_path)
print(f"Modelo guardado en: {modelo_path}")
# Out:
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_59188\296099765.py:13: DtypeWarning: Columns (247) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, encoding='latin-1')
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_59188\296099765.py:103: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace([np.inf, -np.inf], np.nan, inplace=True)
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_59188\296099765.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(X.median(), inplace=True)
# Reporte de clasificación:
# ...

# %% [markdown]
# ## Aplicamos el modelo a diferentes estados de México

# %%
import pandas as pd
import joblib
import numpy as np

# 1. Cargar el modelo entrenado (asegúrate que es el modelo agrupado)
modelo_path = 'modelo_random_forest_agrupado.pkl'  # Cambiado para usar el modelo agrupado
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_ent'].str.upper() == 'AGUASCALIENTES'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Agrupar datos por localidad (igual que en el entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc','nombre']  # Columnas de agrupación

# Primero calcular los totales por localidad
df_grouped_totals = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index()

# Renombrar las columnas de totales
df_grouped_totals = df_grouped_totals.rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# Unir los totales con el dataframe original
df_ags = pd.merge(df_ags, df_grouped_totals, on=columnas_grupo)

# 5. Calcular las variables porcentuales usando los totales sumados (igual que en entrenamiento)
# Replace zeros in denominators with np.nan to avoid division by zero
df_ags['total_viviendas_sum'] = df_ags['total_viviendas_sum'].replace(0, np.nan)
df_ags['poblacion_activa_sum'] = df_ags['poblacion_activa_sum'].replace(0, np.nan)
df_ags['poblacion_total_sum'] = df_ags['poblacion_total_sum'].replace(0, np.nan)

df_ags['vph_excsa'] = limpiar_y_convertir(df_ags['vph_excsa']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_autom'] = limpiar_y_convertir(df_ags['vph_autom']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_inter'] = limpiar_y_convertir(df_ags['vph_inter']) * 100 / df_ags['total_viviendas_sum']
df_ags['pocupada'] = limpiar_y_convertir(df_ags['pocupada']) * 100 / df_ags['poblacion_activa_sum']
df_ags['pder_ss'] = limpiar_y_convertir(df_ags['pder_ss']) * 100 / df_ags['poblacion_total_sum']
df_ags['p18ym_pb'] = limpiar_y_convertir(df_ags['p18ym_pb']) * 100 / df_ags['poblacion_activa_sum']
df_ags['vph_3ymasc'] = limpiar_y_convertir(df_ags['vph_3ymasc']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_stvp'] = limpiar_y_convertir(df_ags['vph_stvp']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_pc'] = limpiar_y_convertir(df_ags['vph_pc']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_cvj'] = limpiar_y_convertir(df_ags['vph_cvj']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_2ymasd'] = limpiar_y_convertir(df_ags['vph_2ymasd']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_moto'] = limpiar_y_convertir(df_ags['vph_moto']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_bici'] = limpiar_y_convertir(df_ags['vph_bici']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_lavad'] = limpiar_y_convertir(df_ags['vph_lavad']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_hmicro'] = limpiar_y_convertir(df_ags['vph_hmicro']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_refri'] = limpiar_y_convertir(df_ags['vph_refri']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_telef'] = limpiar_y_convertir(df_ags['vph_telef']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_spmvpi'] = limpiar_y_convertir(df_ags['vph_spmvpi']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_tv'] = limpiar_y_convertir(df_ags['vph_tv']) * 100 / df_ags['total_viviendas_sum']
df_ags['vph_radio'] = limpiar_y_convertir(df_ags['vph_radio']) * 100 / df_ags['total_viviendas_sum']
df_ags['pder_imss'] = limpiar_y_convertir(df_ags['pder_imss']) * 100 / df_ags['poblacion_activa_sum']
df_ags['vph_1cuart'] = limpiar_y_convertir(df_ags['vph_1cuart']) * 100 / df_ags['total_viviendas_sum']
df_ags['p15sec_co'] = limpiar_y_convertir(df_ags['p15sec_co']) * 100 / df_ags['total_viviendas_sum']
df_ags['p_0a2'] = limpiar_y_convertir(df_ags['p_0a2']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_3a5'] = limpiar_y_convertir(df_ags['p_3a5']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_6a11'] = limpiar_y_convertir(df_ags['p_6a11']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_12a14'] = limpiar_y_convertir(df_ags['p_12a14']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_15a17'] = limpiar_y_convertir(df_ags['p_15a17']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_18a24'] = limpiar_y_convertir(df_ags['p_18a24']) * 100 / df_ags['poblacion_total_sum']
df_ags['pob15_64'] = limpiar_y_convertir(df_ags['pob15_64']) * 100 / df_ags['poblacion_total_sum']
df_ags['p_60ymas'] = limpiar_y_convertir(df_ags['p_60ymas']) * 100 / df_ags['poblacion_total_sum']
df_ags['p12ym_casa'] = limpiar_y_convertir(df_ags['p12ym_casa']) * 100 / df_ags['poblacion_total_sum']
df_ags['p12ym_solt'] = limpiar_y_convertir(df_ags['p12ym_solt']) * 100 / df_ags['poblacion_total_sum']

# Variables para el modelo (sin 'nse' si no está en el modelo agrupado)
variables_modelo = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 
    'p18ym_pb', 'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 
    'vph_2ymasd', 'vph_moto', 'vph_bici', 'vph_lavad', 'vph_hmicro', 
    'vph_refri', 'vph_telef', 'vph_spmvpi', 'graproes', 'vph_tv',
    'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2', 'p_3a5',
    'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt'
]

# Si el modelo incluye 'nse_promedio', agregar esta variable
if 'nse_promedio' in rf_model.feature_names_in_:
    # Calcular promedio de NSE por localidad (si existe la columna 'nse')
    if 'nse' in df_ags.columns:
        orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
        df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
        df_ags['nse_num'] = df_ags['nse'].cat.codes
        
        # Calcular promedio por localidad
        df_grouped_nse = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
        df_grouped_nse = df_grouped_nse.rename(columns={'nse_num': 'nse_promedio'})
        df_ags = pd.merge(df_ags, df_grouped_nse, on=columnas_grupo)
        
        variables_modelo.append('nse_promedio')

# 6. Agrupar los datos por localidad (promedio de las variables porcentuales)
df_ags_grouped = df_ags.groupby(columnas_grupo)[variables_modelo].mean().reset_index()

# 7. Preparar datos para predicción
X_ags = df_ags_grouped[variables_modelo].copy()

# Limpieza de datos
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 8. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 9. Crear DataFrame con resultados
resultados = df_ags_grouped.copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 10. Obtener las variables más importantes (globales)
importancias = rf_model.feature_importances_
top_n = 5
indices_importantes = np.argsort(importancias)[-top_n:][::-1]
variables_importantes = [variables_modelo[i] for i in indices_importantes]

# Añadir variables importantes al resultado
resultados['variables_importantes'] = str(variables_importantes)

# 11. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima', 'variables_importantes']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados:")
print(df_final.head())

# Guardar resultados
output_path = "predicciones_credito_aguascalientes.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_6064\1131453872.py:47: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ags['total_viviendas_sum'] = df_ags['total_viviendas_sum'].replace(0, np.nan)
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_6064\1131453872.py:48: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_ags['poblacion_activa_sum'] = df_ags['poblacion_activa_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_ent'].str.upper() == 'AGUASCALIENTES'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = "predicciones_credito_aguascalientes_corregido.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_59188\178854441.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_59188\178854441.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'TEPIC'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_tepic.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\935084572.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_tepic.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\935084572.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'URIANGATO'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_uriangato.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2840003769.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_uriangato.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2840003769.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'COMPOSTELA'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_compostela.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\281701101.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_compostela.csv"
# Modelo cargado exitosamente
#
# Muestra de resultados con preprocesamiento correcto:
#    nom_ent     nom_mun     nom_loc        nombre  prob_ALTA  prob_BAJA  \
# 0  Nayarit  Compostela  Compostela          ALTO      0.870      0.025
# 1  Nayarit  Compostela  Compostela      AVIACION      0.130      0.045
# 2  Nayarit  Compostela  Compostela  BUENOS AIRES      0.390      0.180
# 3  Nayarit  Compostela  Compostela      CONASUPO      0.375      0.130
# 4  Nayarit  Compostela  Compostela      DE CHILA      0.390      0.155
#
#    prob_MEDIA clasificacion_predicha  prob_maxima
# 0       0.105                   ALTA        0.870
# 1       0.825                  MEDIA        0.825
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'JERÉCUARO'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_jerecuaro.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2002627065.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_jerecuaro.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2002627065.py:100: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
# Muestra de resultados con preprocesamiento correcto:
#       nom_ent    nom_mun    nom_loc       nombre  prob_ALTA  prob_BAJA  \
# 0  Guanajuato  Jerécuaro  Jerécuaro     CHALMITA      0.540      0.090
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'PUERTO VALLARTA'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_sahuayo.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2611272778.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_sahuayo.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2611272778.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_ent'].str.upper() == 'QUERÉTARO'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()
 
# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_queretaro.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\539258086.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_queretaro.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\539258086.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'XALISCO'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_xalisco.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2891692380.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_xalisco.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\2891692380.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_ent'].str.upper() == 'ZACATECAS'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()
 
# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_zacatecas.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\1639200665.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_zacatecas.csv"
# Modelo cargado exitosamente
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_468\1639200665.py:71: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)
# ...

# %%
import pandas as pd
import numpy as np
import joblib

# 1. Cargar el modelo entrenado
modelo_path = 'modelo_random_forest_agrupado.pkl'
rf_model = joblib.load(modelo_path)
print("Modelo cargado exitosamente")

# 2. Cargar y preparar los nuevos datos
df_nuevo = pd.read_excel("07.NSE.xlsx")

# Limpiar nombres de columnas (igual que en el entrenamiento)
df_nuevo.columns = df_nuevo.columns.str.strip().str.lower().str.replace('\n', ' ')

# Filtrar solo Aguascalientes
df_ags = df_nuevo[df_nuevo['nom_mun'].str.upper() == 'MOROLEÓN'].copy()

# 3. Definir función de limpieza (idéntica a la usada en entrenamiento)
def limpiar_y_convertir(columna):
    columna_str = columna.astype(str)
    columna_limpia = columna_str.str.replace('*', '', regex=False)
    return pd.to_numeric(columna_limpia, errors='coerce')

# 4. Columnas para agrupar (deben coincidir con las usadas en entrenamiento)
columnas_grupo = ['nom_ent', 'nom_mun', 'nom_loc', 'nombre']
columnas_grupo = [col for col in columnas_grupo if col in df_ags.columns]

# 5. Variables que se deben sumar antes de calcular porcentaje (igual que en entrenamiento)
variables_a_sumar = [
    'vph_excsa', 'vph_autom', 'vph_inter', 'pocupada', 'pder_ss', 'p18ym_pb',
    'vph_3ymasc', 'vph_stvp', 'vph_pc', 'vph_cvj', 'vph_2ymasd', 'vph_moto',
    'vph_bici', 'vph_lavad', 'vph_hmicro', 'vph_refri', 'vph_telef', 'vph_spmvpi',
    'vph_tv', 'vph_radio', 'pder_imss', 'vph_1cuart', 'p15sec_co', 'p_0a2',
    'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24', 'pob15_64', 'p_60ymas',
    'p12ym_casa', 'p12ym_solt'
]

# Limpiar y convertir las variables antes de sumar (igual que en entrenamiento)
for var in variables_a_sumar:
    if var in df_ags.columns:
        df_ags[var] = limpiar_y_convertir(df_ags[var])

# 6. Sumar variables por localidad (igual que en entrenamiento)
df_sums = df_ags.groupby(columnas_grupo)[variables_a_sumar].sum().reset_index()

# 7. Sumar variables totales para denominadores (igual que en entrenamiento)
df_totales = df_ags.groupby(columnas_grupo).agg({
    'tvivparhab': 'sum',
    'pea': 'sum',
    'pobtot': 'sum'
}).reset_index().rename(columns={
    'tvivparhab': 'total_viviendas_sum',
    'pea': 'poblacion_activa_sum',
    'pobtot': 'poblacion_total_sum'
})

# 8. Unir sumas y totales (igual que en entrenamiento)
df_totales = pd.merge(df_sums, df_totales, on=columnas_grupo)

# 9. Calcular porcentajes con base en totales agrupados (igual que en entrenamiento)
for var in variables_a_sumar:
    if var not in df_totales.columns:
        continue
    if var in ['pocupada', 'pder_imss', 'p18ym_pb']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_activa_sum'].replace(0, np.nan)
    elif var in ['pder_ss', 'p_0a2', 'p_3a5', 'p_6a11', 'p_12a14', 'p_15a17', 'p_18a24',
                 'pob15_64', 'p_60ymas', 'p12ym_casa', 'p12ym_solt']:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['poblacion_total_sum'].replace(0, np.nan)
    else:
        df_totales[var + '_pct'] = df_totales[var] * 100 / df_totales['total_viviendas_sum'].replace(0, np.nan)

# 10. Agregar promedio numérico de NSE por localidad si existe la columna 'nse' (igual que en entrenamiento)
if 'nse' in df_ags.columns and 'nse_promedio' in rf_model.feature_names_in_:
    orden_clases = ['E', 'D', 'D+', 'C-', 'C', 'C+', 'AB']
    df_ags['nse'] = pd.Categorical(df_ags['nse'], categories=orden_clases, ordered=True)
    df_ags['nse_num'] = df_ags['nse'].cat.codes
    df_nse_prom = df_ags.groupby(columnas_grupo)['nse_num'].mean().reset_index()
    df_nse_prom = df_nse_prom.rename(columns={'nse_num': 'nse_promedio'})
    df_totales = pd.merge(df_totales, df_nse_prom, on=columnas_grupo, how='left')

# 11. Seleccionar variables para modelo (deben coincidir exactamente con las usadas en entrenamiento)
variables_pct = [col for col in df_totales.columns if col.endswith('_pct')]
if 'nse_promedio' in df_totales.columns and 'nse_promedio' in rf_model.feature_names_in_:
    variables_pct.append('nse_promedio')

# Verificar que tenemos todas las variables que el modelo espera
missing_vars = set(rf_model.feature_names_in_) - set(variables_pct)
if missing_vars:
    print(f"Advertencia: Faltan variables que el modelo espera: {missing_vars}")
    # Si hay variables faltantes, podemos agregarlas con valores neutrales (como la mediana)
    for var in missing_vars:
        if var not in df_totales.columns:
            df_totales[var] = np.nan

# Asegurarnos de que el orden de las variables coincida exactamente con el entrenamiento
X_ags = df_totales[rf_model.feature_names_in_].copy()

# 12. Limpieza final de datos (igual que en entrenamiento)
X_ags.replace([np.inf, -np.inf], np.nan, inplace=True)
X_ags.fillna(X_ags.median(), inplace=True)

# 13. Predecir probabilidades
probabilidades = rf_model.predict_proba(X_ags)
clases = rf_model.classes_

# 14. Crear DataFrame con resultados
resultados = df_totales[columnas_grupo].copy()
for i, clase in enumerate(clases):
    resultados[f'prob_{clase}'] = probabilidades[:, i]

# Añadir clasificación más probable
resultados['clasificacion_predicha'] = clases[np.argmax(probabilidades, axis=1)]
resultados['prob_maxima'] = np.max(probabilidades, axis=1)

# 15. Obtener las variables más importantes para cada predicción (opcional)
# Esto es más complejo y requeriría acceder a los árboles individuales

# 16. Seleccionar columnas relevantes para el output
columnas_output = columnas_grupo + [f'prob_{clase}' for clase in clases] + ['clasificacion_predicha', 'prob_maxima']

# Crear DataFrame final
df_final = resultados[columnas_output]

# Mostrar primeras filas
print("\nMuestra de resultados con preprocesamiento correcto:")
print(df_final.head())

# Guardar resultados
output_path = ".\Predicciones\predicciones_credito_moroleon.csv"
df_final.to_csv(output_path, index=False, encoding='utf-8-sig')
print(f"\nResultados guardados en: {output_path}")
# Out:
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# <>:130: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\jose.valdez\AppData\Local\Temp\ipykernel_27564\4288918804.py:130: SyntaxWarning: invalid escape sequence '\P'
#   output_path = ".\Predicciones\predicciones_credito_moroleon.csv"
# Modelo cargado exitosamente
#
# Muestra de resultados con preprocesamiento correcto:
#       nom_ent   nom_mun   nom_loc                       nombre  prob_ALTA  \
# 0  Guanajuato  Moroleón  Moroleón             27 DE SEPTIEMBRE   0.305000
# 1  Guanajuato  Moroleón  Moroleón               AVIACION CIVIL   0.215000
# 2  Guanajuato  Moroleón  Moroleón  COLONIA MORELOS (EL PITAYO)   0.367083
# 3  Guanajuato  Moroleón  Moroleón               CONSTITUYENTES   0.340000
# 4  Guanajuato  Moroleón  Moroleón                   CURUMBATIO   0.070000
#
#    prob_BAJA  prob_MEDIA clasificacion_predicha  prob_maxima
# 0    0.20000    0.495000                  MEDIA     0.495000
# ...
